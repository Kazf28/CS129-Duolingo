# %%
import os
import json
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
data = pd.read_csv("Duolingo_Data_02_18.csv")
data
# Out:
#            block_id      token_id    token   pos  \
# 0       block_80999  eiUNqChP0101       La   DET
# 1       block_80999  eiUNqChP0102    femme  NOUN
# 2       block_81000  uUUiSODd0101       Je  PRON
# 3       block_81000  uUUiSODd0102     suis  VERB
# 4       block_81000  uUUiSODd0103    rouge   ADJ
# ...             ...           ...      ...   ...
# 243977  block_44833  B9YtEYi10201    Leurs   DET
# 243978  block_44832  B9YtEYi10102  chapeau  NOUN
# 243979  block_44832  B9YtEYi10101    Votre   DET
# 243980  block_44834  B9YtEYi10301    Notre   DET
# 243981  block_44837  B9YtEYi10602    robes  NOUN
#
#                                                  features    dep_rel  \
# 0          Definite=Def|Gender=Fem|Number=Sing|fPOS=DET++        det
# 1                      Gender=Fem|Number=Sing|fPOS=NOUN++       ROOT
# 2           Number=Sing|Person=1|PronType=Prs|fPOS=PRON++      nsubj
# 3       Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbF...        cop
# 4                       Gender=Fem|Number=Sing|fPOS=ADJ++       ROOT
# ...                                                   ...        ...
# 243977                 Gender=Masc|Number=Plur|fPOS=DET++  nmod:poss
# 243978                Gender=Masc|Number=Sing|fPOS=NOUN++       ROOT
# 243979                 Gender=Masc|Number=Sing|fPOS=DET++  nmod:poss
# 243980                 Gender=Masc|Number=Sing|fPOS=DET++  nmod:poss
# 243981                 Gender=Fem|Number=Plur|fPOS=NOUN++       ROOT
#
#         dep_parent  correctness   user_id             format  ...   client  \
# 0                2            0  +4kwmfjD  reverse_translate  ...      ios
# 1                0            1  +4kwmfjD  reverse_translate  ...      ios
# 2                3            0  +4kwmfjD  reverse_translate  ...      ios
# 3                3            0  +4kwmfjD  reverse_translate  ...      ios
# 4                0            0  +4kwmfjD  reverse_translate  ...      ios
# ...            ...          ...       ...                ...  ...      ...
# 243977           2            0  zNp6qJb4        reverse_tap  ...  android
# 243978           0            0  zNp6qJb4        reverse_tap  ...  android
# 243979           2            0  zNp6qJb4        reverse_tap  ...  android
# 243980           2            0  zNp6qJb4        reverse_tap  ...  android
# 243981           0            0  zNp6qJb4        reverse_tap  ...  android
#
#        session    time churn_time response_time_variance  token_correctness  \
# 0       lesson     3.0        0.0              48.512380           0.163613
# 1       lesson     3.0        0.0              48.512380           0.105323
# 2       lesson     5.0        0.0              48.512380           0.038270
# 3       lesson     5.0        0.0              48.512380           0.062308
# 4       lesson     5.0        0.0              48.512380           0.058091
# ...        ...     ...        ...                    ...                ...
# 243977  lesson  2859.0        1.0           58337.108941           0.300341
# 243978  lesson    10.0        1.0           58337.108941           0.116976
# 243979  lesson    10.0        1.0           58337.108941           0.365617
# 243980  lesson     4.0        1.0           58337.108941           0.282116
# 243981  lesson     3.0        1.0           58337.108941           0.152672
#
#         block_wise_correctness  churn_time_category  time_diff  session_id
# 0                     0.134468                  NaN      0.000           1
# 1                     0.134468                  NaN      0.000           1
# 2                     0.052890                  NaN      0.003           1
# 3                     0.052890                  NaN      0.000           1
# 4                     0.052890                  NaN      0.000           1
# ...                        ...                  ...        ...         ...
# 243977                0.195399                  1.0      0.000           5
# 243978                0.241297                  1.0      0.000           5
# 243979                0.241297                  1.0      0.000           5
# 243980                0.199546                  1.0      0.000           5
# 243981                0.156226                  1.0      0.000           5
#
# [243982 rows x 23 columns]

# %%
features = ["block_wise_correctness","response_time_variance","block_wise_correctness"]
